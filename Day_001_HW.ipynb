# %% [markdown]
# ## 作業一：
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# #### 選擇資料：[Google Play Store Apps on Kaggle](https://www.kaggle.com/lava18/google-play-store-apps)
#
# ##### 1. 你選的這組資料為何重要：
# 可用來理解各種類APP在容量、更新頻率以及使用者屬性（給出的評分以及評論的比例）上的區別。
# ##### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# Web scraping from Google Play Store.
# ##### 3. 蒐集而來的資料型態為何
# App: string, Category: string, Rating: float, Reviews: int, Size: string, Installs: string...
# ##### 4. 這組資料想解決的問題如何評估
# 用Category將資料分群後，可計算上述資料之平均值與標準差

# %% [markdown]
# ## 作業二：
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績應為提升完成之交易量，其他問題如提高獲利空間暫不考慮。
# 提升業績之相似命題應該為降低空車率以及提升市佔率。
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 從App：透過訂車App，可取得訂車時間、上車下車地點、乘客人數等資料。也可取得顧客在App中的個人基本資料。
# 從車子：車上之系統應可紀錄上車下車位置、上車下車時間、付款方式等。
#
# #### 3. 蒐集而來的資料型態為何
# 訂車時間：date
# 上車、下車時間：date
# 上車、下車地點：date
# 乘客人數：int
# 付款方式：string
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 根據上車、訂車時間，再用上車地點分群，可繪製直方圖了解各處於每天不同時段之車輛數量需求。
# 透過個人基本資料以及乘客人數、付款方式，可將使用者分群以近一步了解各族群需求。

# %% [markdown]
# ## 作業三
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    square_error = (y - y_hat) ** 2
    return sum(square_error) / len(y)

# %%
def mean_absolute_error(y, y_hat):
    absolute_error = abs(y - y_hat)
    return sum(absolute_error) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 208.903
# The Mean absolute error is 11.883
